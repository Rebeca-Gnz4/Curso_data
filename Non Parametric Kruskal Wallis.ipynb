# %% [markdown]
# # Tarea 9
# ## Non parametric Kruskal-Wallis

# %%
def import_csv(file):
    import pandas as pd
    return pd.read_csv(file)

# %%
path = "data/Terminos_lagoon_TA_DIC_2023_RawData.csv"

co2_data = import_csv(path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 path = "data/Terminos_lagoon_TA_DIC_2023_RawData.csv"
# ----> 3 co2_data = import_csv(path)
#
# NameError: name 'import_csv' is not defined

# %%
from scipy.stats import kruskal

def kruskal_wallis_test(*groups, alpha=0.05):
    """
    Performs the Kruskal-Wallis H-test for independent samples.
    Accepts multiple groups as arguments.
    Prints the H statistic, p-value, and interpretation.
    """
    result = kruskal(*groups)
    
    print(f"H statistic = {result.statistic}")
    print(f"p-value = {result.pvalue}")
    
    if result.pvalue < alpha:
        print("The difference between groups is statistically significant.")
    else:
        print("No statistically significant difference between groups.")

# %%
# %pip install scikit-posthocs

import scikit_posthocs as sp
# Out:
# Collecting scikit-posthocsNote: you may need to restart the kernel to use updated packages.
#
#   Downloading scikit_posthocs-0.11.4-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: numpy in c:\users\rebec\anaconda3\lib\site-packages (from scikit-posthocs) (2.1.3)
# Requirement already satisfied: scipy>=1.9.0 in c:\users\rebec\anaconda3\lib\site-packages (from scikit-posthocs) (1.15.3)
# Requirement already satisfied: statsmodels in c:\users\rebec\anaconda3\lib\site-packages (from scikit-posthocs) (0.14.4)
# Requirement already satisfied: pandas>=0.20.0 in c:\users\rebec\anaconda3\lib\site-packages (from scikit-posthocs) (2.2.3)
# Requirement already satisfied: seaborn in c:\users\rebec\anaconda3\lib\site-packages (from scikit-posthocs) (0.13.2)
# Requirement already satisfied: matplotlib in c:\users\rebec\anaconda3\lib\site-packages (from scikit-posthocs) (3.10.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\rebec\anaconda3\lib\site-packages (from pandas>=0.20.0->scikit-posthocs) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\rebec\anaconda3\lib\site-packages (from pandas>=0.20.0->scikit-posthocs) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\rebec\anaconda3\lib\site-packages (from pandas>=0.20.0->scikit-posthocs) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\rebec\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=0.20.0->scikit-posthocs) (1.17.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\rebec\anaconda3\lib\site-packages (from matplotlib->scikit-posthocs) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\rebec\anaconda3\lib\site-packages (from matplotlib->scikit-posthocs) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\rebec\anaconda3\lib\site-packages (from matplotlib->scikit-posthocs) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\rebec\anaconda3\lib\site-packages (from matplotlib->scikit-posthocs) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\rebec\anaconda3\lib\site-packages (from matplotlib->scikit-posthocs) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\rebec\anaconda3\lib\site-packages (from matplotlib->scikit-posthocs) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\rebec\anaconda3\lib\site-packages (from matplotlib->scikit-posthocs) (3.2.0)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\rebec\anaconda3\lib\site-packages (from statsmodels->scikit-posthocs) (1.0.1)
# Downloading scikit_posthocs-0.11.4-py3-none-any.whl (33 kB)
# Installing collected packages: scikit-posthocs
# Successfully installed scikit-posthocs-0.11.4

# %%
def dunn_posthoc(data, group_col, value_col, p_adjust='bonferroni'):
    """
    Runs Dunn's post-hoc test after Kruskal-Wallis.
    """
    result = sp.posthoc_dunn(data, val_col=value_col, group_col=group_col, p_adjust=p_adjust)
    print(result)
    return result

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(x='area', y='ta_micromol_kg', data=co2_data)
plt.xlabel('Area of the lagoon')
plt.ylabel('Total Alkalinity (micromol/kg)')
plt.title('Total Alkalinity by Area of the Lagoon')
plt.show()

# %%
ta_river = co2_data[co2_data['area'] == 'River']['ta_micromol_kg']
ta_plume = co2_data[co2_data['area'] == 'Plume']['ta_micromol_kg']
ta_coast= co2_data[co2_data['area'] == 'Coast']['ta_micromol_kg']

# %%
kruskal_wallis_test(ta_river, ta_plume, ta_coast)
# Out:
# H statistic = 23.340675555846637
# p-value = 8.543517259038796e-06
# The difference between groups is statistically significant.

# %%
dunn_posthoc(co2_data, 'area', 'ta_micromol_kg')
# Out:
#           Coast     Plume     River
# Coast  1.000000  1.000000  0.000016
# Plume  1.000000  1.000000  0.000659
# River  0.000016  0.000659  1.000000
#           Coast     Plume     River
# Coast  1.000000  1.000000  0.000016
# Plume  1.000000  1.000000  0.000659
# River  0.000016  0.000659  1.000000

# %% [markdown]
# ## Perform Kruskal-Wallis test and a box plot for DIC data for each area.

# %%
co2_data.columns
# Out:
# Index(['sample', 'date', 'estuary', 'area', 'station', 'layer_depth', 'season',
#        'chlorophy_microg_l', 'cond_microsiemens_cm', 'depth_m',
#        'do_percent_sat', 'do_mg_l', 'sal_psu', 'sp_cond_microsiemens_cm',
#        'turbidity_fnu', 'temp_c', 'latitude', 'longitude', 'dic_micromol_kg',
#        'ta_micromol_kg', 'dummy_data'],
#       dtype='object')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(x='area', y='dic_micromol_kg', data=co2_data, legend=True)
plt.xlabel('Area of the lagoon')
plt.ylabel('DIC (micromol/kg)')
plt.title('DIC by Area of the Lagoon')
plt.show()

# %%
dic_river = co2_data[co2_data['area'] == 'River']['dic_micromol_kg']
dic_plume = co2_data[co2_data['area'] == 'Plume']['dic_micromol_kg']
dic_coast= co2_data[co2_data['area'] == 'Coast']['dic_micromol_kg']

# %%
kruskal_wallis_test(dic_river, dic_plume, dic_coast)
# Out:
# H statistic = 55.889669058187486
# p-value = 7.306553461098262e-13
# The difference between groups is statistically significant.

# %%
dunn_posthoc(co2_data, 'area', 'dic_micromol_kg')
# Out:
#               Coast     Plume         River
# Coast  1.000000e+00  0.063144  7.204720e-13
# Plume  6.314392e-02  1.000000  1.885873e-06
# River  7.204720e-13  0.000002  1.000000e+00
#               Coast     Plume         River
# Coast  1.000000e+00  0.063144  7.204720e-13
# Plume  6.314392e-02  1.000000  1.885873e-06
# River  7.204720e-13  0.000002  1.000000e+00

# %% [markdown]
# ## Perform Kruskal-Wallis test and a box plot for Tempearature data for each area.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(x='area', y='temp_c', data=co2_data, legend=True) 
plt.xlabel('Area of the lagoon')
plt.ylabel('temperature (°C)')
plt.title('Temperature by Area of the Lagoon')
plt.show()

# %%
temp_river = co2_data[co2_data['area'] == 'River']['temp_c']
temp_plume = co2_data[co2_data['area'] == 'Plume']['temp_c']
temp_coast= co2_data[co2_data['area'] == 'Coast']['temp_c']

# %%
kruskal_wallis_test(temp_river, temp_plume, temp_coast)
# Out:
# H statistic = 7.6996429549091365
# p-value = 0.021283535690208223
# The difference between groups is statistically significant.

# %%
dunn_posthoc(co2_data, 'area', 'dic_micromol_kg')
# Out:
#               Coast     Plume         River
# Coast  1.000000e+00  0.063144  7.204720e-13
# Plume  6.314392e-02  1.000000  1.885873e-06
# River  7.204720e-13  0.000002  1.000000e+00
#               Coast     Plume         River
# Coast  1.000000e+00  0.063144  7.204720e-13
# Plume  6.314392e-02  1.000000  1.885873e-06
# River  7.204720e-13  0.000002  1.000000e+00
